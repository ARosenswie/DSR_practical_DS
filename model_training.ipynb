# %% [markdown]
# # Customer Churn Prediction Model
#
# Using the [Telco customer churn data](https://www.kaggle.com/code/mechatronixs/telco-churn-prediction-feature-engineering-eda/data) from kaggle, train a machine learning model to predict customer churn.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import seaborn as sns

# %%
# get training data
train = pd.read_csv("./data/training_data.csv")
# drop customer ID: not a feature for training 
train.drop("customerID", axis=1, inplace=True)

# getting validation data
val = pd.read_csv("./data/validation_data.csv")

# %%
customer_row = {
'gender': gender,
'SeniorCitizen': senior_citizen}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 customer_row = {
# ----> 2 'gender': gender,
#       3 'SeniorCitizen': senior_citizen}
#
# NameError: name 'gender' is not defined

# %%
train.shape
# Out:
# (5282, 20)

# %%
train.head()
# Out:
#   gender  SeniorCitizen Partner Dependents  tenure PhoneService MultipleLines
# 0   Male              0      No         No       5          Yes            No  \
# 1   Male              0     Yes         No      66          Yes           Yes
# 2   Male              0     Yes        Yes      42          Yes            No
# 3   Male              0      No         No      19          Yes           Yes
# 4   Male              0      No         No      59          Yes            No
#
#   InternetService       OnlineSecurity         OnlineBackup
# 0             DSL                   No                   No  \
# 1             DSL                   No                   No
# 2             DSL                   No                   No
# 3             DSL                   No                   No
# 4              No  No internet service  No internet service
#
#       DeviceProtection          TechSupport          StreamingTV
# 0                  Yes                  Yes                  Yes  \
# 1                   No                  Yes                   No
# 2                  Yes                  Yes                  Yes
# 3                   No                   No                  Yes
# 4  No internet service  No internet service  No internet service
#
#        StreamingMovies        Contract PaperlessBilling
# 0                  Yes  Month-to-month               No  \
# 1                  Yes  Month-to-month               No
# 2                  Yes        One year               No
# 3                  Yes  Month-to-month               No
# 4  No internet service        Two year              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges Churn
# 0  Bank transfer (automatic)           75.15       392.65    No
# 1           Electronic check           63.85       4264.6    No
# 2           Electronic check           73.15      3088.25    No
# 3               Mailed check           69.60      1394.55    No
# 4  Bank transfer (automatic)           20.20       1192.3    No

# %% [markdown]
# ## We need to encode the values within a column. Here, we use Scikit Learn to encode specified columns.

# %%
# le = LabelEncoder()
# le.fit(train['gender'])
# le.transform(train['gender'])
# train.shape
# train.head()

# %% [markdown]
# Create a dictionary for all data that is non-numeric.

# %%
categorical_columns = ['gender', 'Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
        'Churn']

# %% [markdown]
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
column_mapper = {}

for column in categorical_columns:
    le = LabelEncoder()
    le.fit(train.loc[:,column])
    column_mapper[column] = le

# %%
train.head()
# Out:
#   gender  SeniorCitizen Partner Dependents  tenure PhoneService MultipleLines
# 0   Male              0      No         No       5          Yes            No  \
# 1   Male              0     Yes         No      66          Yes           Yes
# 2   Male              0     Yes        Yes      42          Yes            No
# 3   Male              0      No         No      19          Yes           Yes
# 4   Male              0      No         No      59          Yes            No
#
#   InternetService       OnlineSecurity         OnlineBackup
# 0             DSL                   No                   No  \
# 1             DSL                   No                   No
# 2             DSL                   No                   No
# 3             DSL                   No                   No
# 4              No  No internet service  No internet service
#
#       DeviceProtection          TechSupport          StreamingTV
# 0                  Yes                  Yes                  Yes  \
# 1                   No                  Yes                   No
# 2                  Yes                  Yes                  Yes
# 3                   No                   No                  Yes
# 4  No internet service  No internet service  No internet service
#
#        StreamingMovies        Contract PaperlessBilling
# 0                  Yes  Month-to-month               No  \
# 1                  Yes  Month-to-month               No
# 2                  Yes        One year               No
# 3                  Yes  Month-to-month               No
# 4  No internet service        Two year              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges Churn
# 0  Bank transfer (automatic)           75.15       392.65    No
# 1           Electronic check           63.85       4264.6    No
# 2           Electronic check           73.15      3088.25    No
# 3               Mailed check           69.60      1394.55    No
# 4  Bank transfer (automatic)           20.20       1192.3    No

# %%
def pre_process_data(df, label_encoder_dict):
    df_out = df.copy()
    df_out.replace(' ', 0, inplace=True)
    df_out.loc[:, 'TotalCharges'] = pd.to_numeric(df_out.loc[:, 'TotalCharges'])
    if 'customerID' in df_out.columns:
        df_out.drop('customerID', axis=1, inplace=True)
    for column, le in label_encoder_dict.items():
        df_out.loc[:, column] = le.transform(df_out.loc[:, column])
        
    return df_out

# %%
train_processed = pre_process_data(train, column_mapper)
val_processed = pre_process_data(val, column_mapper)

# %%
train
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService
# 0       Male              0      No         No       5          Yes  \
# 1       Male              0     Yes         No      66          Yes
# 2       Male              0     Yes        Yes      42          Yes
# 3       Male              0      No         No      19          Yes
# 4       Male              0      No         No      59          Yes
# ...      ...            ...     ...        ...     ...          ...
# 5277    Male              0      No         No       1          Yes
# 5278    Male              0     Yes         No       2          Yes
# 5279  Female              0     Yes         No      58          Yes
# 5280  Female              0      No         No       1          Yes
# 5281  Female              0      No        Yes       4          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup
# 0               No             DSL                   No                   No  \
# 1              Yes             DSL                   No                   No
# 2               No             DSL                   No                   No
# 3              Yes             DSL                   No                   No
# 4               No              No  No internet service  No internet service
# ...            ...             ...                  ...                  ...
# 5277            No              No  No internet service  No internet service
# 5278            No     Fiber optic                   No                   No
# 5279           Yes             DSL                  Yes                   No
# 5280            No     Fiber optic                   No                  Yes
# 5281           Yes     Fiber optic                   No                  Yes
#
#          DeviceProtection          TechSupport          StreamingTV
# 0                     Yes                  Yes                  Yes  \
# 1                      No                  Yes                   No
# 2                     Yes                  Yes                  Yes
# 3                      No                   No                  Yes
# 4     No internet service  No internet service  No internet service
# ...                   ...                  ...                  ...
# 5277  No internet service  No internet service  No internet service
# 5278                  Yes                   No                   No
# 5279                   No                  Yes                   No
# 5280                   No                   No                   No
# 5281                  Yes                   No                   No
#
#           StreamingMovies        Contract PaperlessBilling
# 0                     Yes  Month-to-month               No  \
# 1                     Yes  Month-to-month               No
# 2                     Yes        One year               No
# 3                     Yes  Month-to-month               No
# 4     No internet service        Two year              Yes
# ...                   ...             ...              ...
# 5277  No internet service  Month-to-month               No
# 5278                   No  Month-to-month               No
# 5279                  Yes        One year              Yes
# 5280                   No  Month-to-month              Yes
# 5281                   No  Month-to-month               No
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 0     Bank transfer (automatic)           75.15       392.65    No
# 1              Electronic check           63.85       4264.6    No
# 2              Electronic check           73.15      3088.25    No
# 3                  Mailed check           69.60      1394.55    No
# 4     Bank transfer (automatic)           20.20       1192.3    No
# ...                         ...             ...          ...   ...
# 5277  Bank transfer (automatic)           20.20         20.2    No
# 5278           Electronic check           76.40        151.8   Yes
# 5279           Electronic check           68.40      3972.25    No
# 5280           Electronic check           75.70         75.7   Yes
# 5281  Bank transfer (automatic)           84.05       333.55   Yes
#
# [5282 rows x 20 columns]

# %%
#sns.pairplot(val_processed)

# %%
x_train = train_processed.drop('Churn', axis=1)
y_train = train_processed.loc[:, 'Churn'].astype(int)

# %%
x_val = val_processed.drop('Churn', axis=1)
y_val = val_processed.loc[:, 'Churn'].astype(int)

# %% [markdown]
# ## Create a Linear Regression Classifier.

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
pred = model.predict(x_val)

# %%
pd.DataFrame(model.coef_, columns=x_val.columns)
# Out:
#      gender  SeniorCitizen   Partner  Dependents    tenure  PhoneService
# 0 -0.033813       0.294475  0.090014   -0.209555 -0.065813     -0.758055  \
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup
# 0        0.09118         0.102603       -0.297117     -0.192053  \
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract
# 0         -0.119016    -0.229671     0.017049         0.023654 -0.717679  \
#
#    PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges
# 0          0.340855       0.016659        0.020393      0.000372

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_val, pred)
print("Accuracy: {:.3f}".format(accuracy))
# Out:
# Accuracy: 0.836

# %%
import pickle

with open('./models/churn_predicition_model.pkl', 'wb') as pickler:
    pickle.dump(model, pickler)
    
with open('./models/churn_predicition_label_encoder.pkl', 'wb') as pickler:
    pickle.dump(column_mapper, pickler)
